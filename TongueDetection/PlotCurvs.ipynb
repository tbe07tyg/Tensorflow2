# %%
# plot curves from the saved results
import pickle
Sen_name = "Sen"
Spe_name = "Spe"
Acc_name =  "Acc"
Pre_name = "Pre"
Sen_name2 = "Sen_plus"
Spe_name2 = "Spe_plus"
Acc_name2 =  "Acc_plus"
Pre_name2 = "Pre_plus"
with open (Sen_name, 'rb') as fp:
    Sen1_list = pickle.load(fp)
with open (Spe_name, 'rb') as fp:
    Spe1_list = pickle.load(fp)
with open (Spe_name, 'rb') as fp:
    Acc1_list = pickle.load(fp)
with open (Pre_name, 'rb') as fp:
    Pre1_list = pickle.load(fp)
    
    
with open (Sen_name2, 'rb') as fp:
    Sen2_list = pickle.load(fp)
with open (Spe_name2, 'rb') as fp:
    Spe2_list = pickle.load(fp)
with open (Acc_name2, 'rb') as fp:
    Acc2_list = pickle.load(fp)
with open (Pre_name2, 'rb') as fp:
    Pre2_list = pickle.load(fp)

# %%
# def plot_roc(name, labels, predictions, **kwargs):
#   fp, tp, _ = sklearn.metrics.roc_curve(labels, predictions)

#   plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
#   plt.xlabel('False positives [%]')
#   plt.ylabel('True positives [%]')
#   plt.xlim([-0.5,20])
#   plt.ylim([80,100.5])
#   plt.grid(True)
#   ax = plt.gca()
#   ax.set_aspect('equal')
from matplotlib import pyplot as plt
plt.figure(figsize=(4, 3))
def plot_roc(fpr, sen, label):


  plt.plot(fpr, sen, label=label, linewidth=2)
  plt.xlabel('1-Specificity')
  plt.ylabel('Sensitivity')
  plt.xlim([0, 0.7])
  plt.ylim([0.2, 1])
  plt.grid(True)
  ax = plt.gca()
  ax.set_aspect('equal')

import numpy as np    
print("spe1:", Spe1_list)
print("sen1:", Sen1_list)
fpr =  1-np.array(Spe1_list)
print("fpr:", fpr)
plot_roc(1-np.array(Spe1_list), np.array(Sen1_list), label="Case 2")
# plot_roc(1-np.array(Spe2_list), np.array(Sen2_list), label="Case 3")
plt.legend(loc='lower left')
# Out:
# spe1: [0.9, 0.9, 0.9, 0.8823529411764706, 0.8823529411764706, 0.8823529411764706, 0.8333333333333334, 0.6923076923076923, 0.4787234042553192, 0.32608695652173914]
# sen1: [0.95, 0.95, 0.95, 0.9494949494949495, 0.9494949494949495, 0.9494949494949495, 0.9479166666666666, 0.9411764705882353, 0.9107142857142857, 0.5833333333333334]
# fpr: [0.1        0.1        0.1        0.11764706 0.11764706 0.11764706
#  0.16666667 0.30769231 0.5212766  0.67391304]

# %%
# plot pr curve
def plot_rp(sen, pre, label):


  plt.plot(sen, pre, label=label, linewidth=2)
  plt.xlabel('Recall')
  plt.ylabel('Precision')
#   plt.xlim([0, 0.7])
#   plt.ylim([0.2, 1])
  plt.grid(True)
  ax = plt.gca()
  ax.set_aspect('equal')
plt.figure(figsize=(4, 3))    
plot_rp(Sen1_list, Pre1_list, label="Case 2")
# plot_rp(Sen1_list, Pre2_list, label="Case 3")
plt.legend(loc='lower left')

# %%
IOU_TH = np.linspace(0.5, 0.95, num=10)
# plot
plt.figure(figsize=(4, 3))  
def plot_ioU_y(iou_list, y, label):


  plt.plot(iou_list, y, label=label, linewidth=2)
  plt.xlabel('IoUs')
  plt.ylabel('Specificity')
  plt.xlim([0.5, 1])
#   plt.ylim([0.2, 1])
  plt.grid(True)
  ax = plt.gca()
#   ax.set_aspect('equal')
    
# plt.figure(figsize=(3, 4))    
# plot_ioU_y(IOU_TH, Spe1_list, label="Specificity 1", marker="*")
# plot_ioU_y(IOU_TH, Spe2_list, label="Specificity 2", marker="*")
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pylab import cm
import matplotlib.font_manager as fm
# Collect all the font names available to matplotlib
font_names = [f.name for f in fm.fontManager.ttflist]
print(font_names)

import matplotlib.font_manager as fm
# Rebuild the matplotlib font cache
fm._rebuild()
mpl.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 18
plt.rcParams['axes.linewidth'] = 2

# Generate 2 colors from the 'tab10' colormap
colors = cm.get_cmap('tab10', 2)
# Create figure object and store it in a variable called 'fig'
fig = plt.figure(figsize=(4, 3))
# Add axes object to our figure that takes up entire figure
ax = fig.add_axes([0, 0, 1, 1])

# Edit the major and minor ticks of the x and y axes
ax.xaxis.set_tick_params(which='major', size=5, width=2, direction='in', top='on')
ax.xaxis.set_tick_params(which='minor', size=5, width=2, direction='in', top='on')
ax.yaxis.set_tick_params(which='major', size=5, width=2, direction='in', right='on')
ax.yaxis.set_tick_params(which='minor', size=5, width=2, direction='in', right='on')
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(0.95))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(0.5))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(0))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# plot
# ax.plot(wavelength, samp_1_abs, linewidth=2, color=colors(0), label='Sample 1')
# ax.plot(wavelength, samp_2_abs, linewidth=2, color=colors(1), label='Sample 2')

plt.plot(IOU_TH, Spe1_list, label="Spe. Case 2", linewidth=2, marker="*", color='r')
plt.plot(IOU_TH, Spe2_list, label="Spe. Case 3", linewidth=2, marker="8", color='r')
plt.plot(IOU_TH, Sen1_list, label="Sen. Case 2", linewidth=2, marker="*", alpha=0.7, color='C1')
plt.plot(IOU_TH, Sen2_list, label="Sen. Case 3", linewidth=2, marker="8", alpha=0.7, color='C1')
plt.plot(IOU_TH, Acc1_list, label="Acc. Case 2", linewidth=2, marker="*", alpha=0.5, color='g', linestyle='dashed')
plt.plot(IOU_TH, Acc2_list, label="Acc. Case 3", linewidth=2, marker="8", alpha=0.5, color='g', linestyle='dashed')
plt.xlabel('IoUs [0.5, 0.95]')
plt.ylabel('Values')
# plot_rp(Sen1_list, Pre2_list, label="Case 3")
# Add legend to plot
ax.legend(loc="lower left", fontsize=16)
# Save figure
plt.savefig('ReSultsCompare.png', dpi=300, transparent=False, bbox_inches='tight')
# Out:
# ['DejaVu Sans Mono', 'cmss10', 'STIXSizeOneSym', 'DejaVu Serif', 'DejaVu Sans', 'STIXSizeFourSym', 'STIXNonUnicode', 'cmmi10', 'STIXGeneral', 'cmtt10', 'DejaVu Sans', 'STIXGeneral', 'STIXSizeOneSym', 'DejaVu Sans Mono', 'cmb10', 'cmr10', 'DejaVu Serif', 'cmex10', 'DejaVu Serif Display', 'DejaVu Serif', 'STIXGeneral', 'cmsy10', 'STIXSizeThreeSym', 'STIXNonUnicode', 'STIXNonUnicode', 'DejaVu Serif', 'DejaVu Sans', 'DejaVu Sans', 'STIXGeneral', 'DejaVu Sans Display', 'STIXNonUnicode', 'STIXSizeThreeSym', 'STIXSizeFiveSym', 'STIXSizeTwoSym', 'STIXSizeTwoSym', 'DejaVu Sans Mono', 'DejaVu Sans Mono', 'STIXSizeFourSym', 'Bookman Old Style', 'Myriad Pro', 'Segoe UI Symbol', 'Georgia', 'Kozuka Gothic Pr6N', 'Myriad Hebrew', 'Bookman Old Style', 'Arvo', 'Californian FB', 'Euclid Symbol', 'Kozuka Gothic Pro', 'SimHei', 'Ebrima', 'Goudy Old Style', 'Onyx', 'Euclid Extra', 'FZShuTi', 'HP Simplified', 'Gotham', 'Britannic Bold', 'Colonna MT', 'Lobster', 'Tekton Pro', 'Microsoft Yi Baiti', 'Candara
# ...
