# %%
# generate gif
from IPython import display
import imageio
from glob import glob
# 1
# root_read = "E:\\Projects\\logs\\dicoms\\fixedArranged\\fixed\\1Bleed_AE_L1_CE_Sigmoid_NormFull\\AE_saves\\Predictions"
# 2
# root_read = "E:\\Projects\\logs\\dicoms\\fixedArranged\\fixed\\2Bleed_AE_L1_CE_Sigmoid_NormNarrow_NoShuffle\\AE_saves\\Predictions"

# 3
# root_read = "E:\\Projects\\logs\\dicoms\\fixedArranged\\fixed\\3Bleed_AE_L1_CE_Sigmoid_NormNarrow_ShuffleTr\\AE_saves\\Predictions"
# anim_file = root_write +'/AE_saves3.gif'

#4 
# root_read = "E:\\Projects\\logs\\dicoms\\fixedArranged\\fixed\\4Bleed_AE_L1_BCE_Sigmoid_NormNarrow_ShuffleTr_SaveBest\\AE_saves\\Predictions"
# anim_file = root_write +'/AE_saves4.gif'

# #5
# root_read = "E:\\Projects\\logs\\dicoms\\fixedArranged\\fixed\\5Bleed_AE_L1Only_Sigmoid_NormNarrow_ShuffleTr_SaveBest\\AE_saves\\Predictions"
# anim_file = root_write +'/AE_saves5.gif'

#6
# root_read = "E:\\Projects\\logs\\dicoms\\fixedArranged\\fixed\\6Bleed_AE_Huber_Sigmoid_NormNarrow_ShuffleTr_SaveBest\\AE_saves\\Predictions"
# anim_file = root_write +'/AE_saves6.gif'

#7
# root_read = "E:\\Projects\\logs\\dicoms\\fixedArranged\\fixed\\7Bleed_AE_Huber_BCE_Sigmoid_NormNarrow_ShuffleTr_SaveBest\\AE_saves\\Predictions"
# anim_file = root_write +'/AE_saves7.gif'

#8
# root_read = "E:\\Projects\\logs\\dicoms\\fixedArranged\\fixed\\8Bleed_AE_Huber_BCE_Sigmoid_NormNarrow_ShuffleTr_RandWinTrTe_SaveBest\\AE_saves"
# anim_file = root_write +'/AE_saves8.gif'

# 9 SegAndCls
root_read = "E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid"
root_write = "E:\\Projects\\TF2\\SublingualVein\\2020May\\Glfs"
anim_file = root_write +'/MassCentroids224.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
    path_read =  root_read + '/*.png'
    print("path_read", path_read)
    filenames = glob(root_read + '/*.png')
    print(filenames)
    filenames = sorted(filenames)
    print(len(filenames))
    last = -1
    for i,filename in enumerate(filenames):
        frame = 2*(i**0.5)
        if round(frame) > round(last):
          last = frame
        else:
          continue
        image = imageio.imread(filename)
        writer.append_data(image)
        image = imageio.imread(filename)
        writer.append_data(image)

import IPython
if IPython.version_info >= (6,2,0,''):
  display.Image(filename=anim_file)
# Out:
# path_read E:\dataset\SublingualVein\TIASRGB2020\train_left_right_binary_label\left_with_mass_centroid/*.png
# ['E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\1002dozono01 (1).png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\1002dozono01 (10).png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\1002dozono01 (2).png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\1002dozono01 (3).png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\1002dozono01 (4).png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\1002dozono01 (5).png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\1002dozono01 (6).png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\1002dozono01 (7).png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\1002dozono01 (8).png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\1002dozono01 (9).png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\do1.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\do10.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\do2.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\do3.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\do4.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\do5.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\do6.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\do7.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\do8.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\do9.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\ito01.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\ito02.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\ito03.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\ito04.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\ito05.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\ito06.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\ito07.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\ito08.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\ito09.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\ito10.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\kathy_0.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\kathy_1.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\kathy_10.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\kathy_2.png', 'E:\\dataset\\SublingualVein\\TIASRGB2020\\train_left_right_binary_label\\left_with_mass_centroid\\kathy_3.png', 'E:\\datase ...
# 219
